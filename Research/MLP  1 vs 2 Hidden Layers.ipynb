# %%
# Training on CPU with 1 Hidden Layer

# %%
# Trial 1 
# %run main.py
# Out:
# Using cpu device
# Torch Version:  2.8.0+cpu
# CUDA Available: False
#
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )
# Train Epoch: 1 [0/60000  (0%)]	2.314565
# Train Epoch: 1 [20000/60000  (33%)]	0.208269
# Train Epoch: 1 [40000/60000  (67%)]	0.191077
# Train Epoch: 1 [59900/60000  (100%)]	0.097198
#
# Test set: Average loss: 0.0011, Accuracy 9654/10000 (97%
# )
# Train Epoch: 2 [0/60000  (0%)]	0.118207
# Train Epoch: 2 [20000/60000  (33%)]	0.154285
# Train Epoch: 2 [40000/60000  (67%)]	0.061693
# Train Epoch: 2 [59900/60000  (100%)]	0.043092
#
# Test set: Average loss: 0.0008, Accuracy 9743/10000 (97%
# )
# Train Epoch: 3 [0/60000  (0%)]	0.024586
# Train Epoch: 3 [20000/60000  (33%)]	0.028548
# ...

# %%
# Trial 2 
# %run main.py
# Out:
# Using cpu device
# Torch Version:  2.8.0+cpu
# CUDA Available: False
#
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )
# Train Epoch: 1 [0/60000  (0%)]	2.300009
# Train Epoch: 1 [20000/60000  (33%)]	0.286899
# Train Epoch: 1 [40000/60000  (67%)]	0.128256
# Train Epoch: 1 [59900/60000  (100%)]	0.080775
#
# Test set: Average loss: 0.0011, Accuracy 9648/10000 (96%
# )
# Train Epoch: 2 [0/60000  (0%)]	0.115459
# Train Epoch: 2 [20000/60000  (33%)]	0.048785
# Train Epoch: 2 [40000/60000  (67%)]	0.127818
# Train Epoch: 2 [59900/60000  (100%)]	0.055596
#
# Test set: Average loss: 0.0008, Accuracy 9767/10000 (98%
# )
# Train Epoch: 3 [0/60000  (0%)]	0.031047
# Train Epoch: 3 [20000/60000  (33%)]	0.022698
# ...

# %%
# Trial 3
# %run main.py
# Out:
# Using cpu device
# Torch Version:  2.8.0+cpu
# CUDA Available: False
#
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )
# Train Epoch: 1 [0/60000  (0%)]	2.306983
# Train Epoch: 1 [20000/60000  (33%)]	0.279099
# Train Epoch: 1 [40000/60000  (67%)]	0.186999
# Train Epoch: 1 [59900/60000  (100%)]	0.087844
#
# Test set: Average loss: 0.0011, Accuracy 9659/10000 (97%
# )
# Train Epoch: 2 [0/60000  (0%)]	0.054308
# Train Epoch: 2 [20000/60000  (33%)]	0.092657
# Train Epoch: 2 [40000/60000  (67%)]	0.258553
# Train Epoch: 2 [59900/60000  (100%)]	0.098967
#
# Test set: Average loss: 0.0008, Accuracy 9742/10000 (97%
# )
# Train Epoch: 3 [0/60000  (0%)]	0.084372
# Train Epoch: 3 [20000/60000  (33%)]	0.070940
# ...
